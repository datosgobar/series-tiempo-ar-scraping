# %%
import pandas as pd

# %%
distrib = pd.read_excel("/Users/abenassi/github/series-tiempo/data/input/catalog/sspm/catalog.xlsx", "Distribution")

# %%
from pydatajson.helpers import title_to_name

# %%
for f in distrib.distribution_title.apply(title_to_name):
    print(f + ".csv")
# Out:
# oferta-demanda-globales-precios-1993-datos-desestacionalizados-valores-anuales-base-1993.csv
# oferta-demanda-globales-precios-1993-datos-desestacionalizados-valores-trimestrales-base-1993.csv
# oferta-demanda-globales-precios-1993-valores-anuales-base-1993.csv
# oferta-demanda-globales-precios-1993-valores-trimestrales-base-1993.csv
# oferta-demanda-globales-precios-corrientes-valores-anuales-base-1993.csv
# oferta-demanda-globales-precios-corrientes-valores-trimestrales-base-1993.csv
# oferta-demanda-globales-precios-2004-datos-desestacionalizados-valores-anuales-base-2004.csv
# oferta-demanda-globales-precios-2004-datos-desestacionalizados-valores-trimestral-base-2004.csv
# oferta-demanda-globales-precios-2004-valores-anuales-base-2004.csv
# oferta-demanda-globales-precios-2004-valores-trimestrales-base-2004.csv
# oferta-demanda-globales-precios-corrientes-valores-anuales-base-2004.csv
# oferta-demanda-globales-precios-corrientes-valores-trimestrales-base-2004.csv
# ...
