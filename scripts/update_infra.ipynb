# %% [markdown]
# # Pruebas ETL de series de tiempo

# %%
import os
from copy import deepcopy
import pandas as pd
import pysftp
import requests
import yaml
from pydatajson import DataJson
import time 
from bs4 import BeautifulSoup
import dataset
from pprint import pprint

from xlseries import XlSeries
from pydatajson import readers
from sqlalchemy import create_engine

from scrape_datasets import scrape_distribution
from scrape_datasets import scrape_dataset, scrape_file
from paths import *

catalog_xlsx_path = os.path.join(DATOS_DIR, "catalogo-sspm.xlsx")
catalog_json_path = os.path.join(CATALOGS_DIR, "catalog", "sspm", "data.json")
test_catalog_json_path = os.path.join(DATOS_DIR, "tests", "catalog", "sspm", "data.json")
etl_params_path = os.path.join(DATOS_DIR, "params", "etl_params.csv")

etl_params = pd.read_csv(etl_params_path, dtype={"distribution_identifier": "str"})
catalog = readers.read_catalog(catalog_json_path)

cnopts = pysftp.CnOpts()
# cnopts.hostkeys.load('/Users/abenassi/.ssh/known_hosts')
cnopts.hostkeys = None
config_ind_path="config/config_ind.yaml"

with open(config_ind_path, 'r') as f:
        ind_params = yaml.load(f)

# %%
db_con_url = 'postgresql://{user}:{password}@{host}:{port}/{db}'.format(
        host=ind_params["db"]["host"],
        port=ind_params["db"]["port"],
        user=ind_params["db"]["user"],
        password=ind_params["db"]["pass"],
        db=ind_params["db"]["db"]
)
engine = create_engine(db_con_url)
db = dataset.connect(db_con_url)

# %%
db.tables
# Out:
# [u'archivo_permitidos',
#  u'permisos_catalog',
#  u'dataset',
#  u'archivo',
#  u'databasechangelog',
#  u'ad_esp_permitidos',
#  u'jhi_authority',
#  u'ad_esp',
#  u'field',
#  u'jhi_persistent_audit_evt_data',
#  u'jhi_user_authority',
#  u'ad_esp_tecnica',
#  u'catalog_tematica_global',
#  u'catalog_permitidos',
#  u'ad_attachment',
#  u'dataset_tematica_especifica',
#  u'ad_status',
#  u'databasechangeloglock',
#  u'dataset_permitidos',
#  u'catalog_tematica_especifica',
#  u'jhi_user',
#  u'catalog',
#  u'jhi_persistent_audit_event',
#  u'dataset_tematica_global',
#  u'distribution']

# %% [markdown]
# ## Upload data y metadata

# %%
def do_ind_api_request(distribution_id_ind=None, req_type="data", 
                       config_ind="config/config_ind.yaml"):
    
    if isinstance(config_ind, dict):
        ind_params = config_ind
    else:
        with open(config_ind, 'r') as f:
            ind_params = yaml.load(f)

    # request original
    headers = {"Authorization": ind_params["api"]["auth_header"]}
    if req_type == "metadata":
        url = ind_params["api"][req_type]["url"]
    elif req_type == "data":
        url = ind_params["api"][req_type]["url"].format(distribution_id_ind)
    else:
        raise Exception("{} no es un tipo de request valido".format(
            req_type))
    print(url)

    res = requests.get(url, headers=headers)
    print(res.content)
    
    req_id = BeautifulSoup(res.content).find("id").get_text()
    
    # request de status con bloqueo hasta finalizar
    job_completed = False
    while not job_completed:
        headers_status = {
            "Authorization": ind_params["api"]["auth_header"]
        }
        url_status = ind_params["api"]["job_status"]["url"].format(req_id)
        res_status = requests.get(url_status, headers=headers_status)
        bs = BeautifulSoup(res_status.content)
        
        # chequea el estado para saber si seguir esperando o terminar
        try:
            status = bs.find("status_desc").get_text()
            if status == "Running":
                time.sleep(0.3)
            else:
                job_completed = True
        except:
            job_completed = True
    
    return bs

# %%
def upload_file_to_ind(local_path, remote_dir=None, file_name=None, config_ind="config/config_ind.yaml"):
    """Carga de un archivo a la infraestructura."""

    if isinstance(config_ind, dict):
        ind_params = config_ind
    else:
        with open(config_ind, 'r') as f:
            ind_params = yaml.load(f)

    remote_dir = remote_dir or '/home/{}'.format(ind_params["api"]["user"])

    with pysftp.Connection(ind_params["api"]["host"], username=ind_params["api"]["user"], 
                           password=ind_params["api"]["pass"], cnopts=cnopts) as sftp:
    
        with sftp.cd(remote_dir):
            if file_name:
                remote_path = os.path.join(remote_dir, file_name)

                print("Local: {} / Remote: {}".format(local_path, remote_path))
                res = sftp.put(local_path, remote_path)

                while not sftp.exists(remote_path):
                    time.sleep(0.2)

                return res
            else:
                res = sftp.put(local_path)

                return res

# %%
def upload_datajson_to_ind(local_path, config_ind_path="config/config_ind.yaml"):
    
    with open(config_ind_path, 'r') as f:
        ind_params = yaml.load(f)
        
    upload_file_to_ind(local_path, config_ind=ind_params)

    status = do_ind_api_request(req_type="metadata", config_ind=ind_params)

    return status

# %%
def upload_distribution_to_ind(local_path, distribution_id, config_ind_path="config/config_ind.yaml"):
    
    with open(config_ind_path, 'r') as f:
        ind_params = yaml.load(f)
        
    file_name = "{}.csv".format(distribution_id)
    upload_file_to_ind(local_path, file_name=file_name, config_ind=ind_params)

    status = do_ind_api_request(distribution_id_ind=distribution_id,
        req_type="data", config_ind=ind_params)

    return status

# %%
def get_distribution_ind_ids(config_ind_path="config/config_ind.yaml"):
    with open(config_ind_path, 'r') as f:
        ind_params = yaml.load(f)
        
    query = """
        SELECT
            ct.id_catalog, ct.nombre, ds.id_distribution, ds.identificador
        FROM distribution ds
            inner join dataset dt on (dt.id_dataset = ds.id_dataset)
            inner join catalog ct on (dt.id_catalog= ct.id_catalog)
        WHERE 
            ds.vigente = TRUE and 
            dt.vigente = TRUE and 
            ct.vigente = TRUE;
    """

    engine = create_engine('postgresql://{user}:{password}@{host}:{port}/modernizacion'.format(
        host=ind_params["db"]["host"],
        port=ind_params["db"]["port"],
        user=ind_params["db"]["user"],
        password=ind_params["db"]["pass"]
    ))
    
    index_cols = ["nombre", "identificador"]
    df_distribs = pd.read_sql_query(query, engine).dropna().sort_values(index_cols)
    df = df_distribs.drop_duplicates(index_cols, keep="last").set_index(index_cols)
    df.sort_index(level=index_cols, ascending=[1, 0], inplace=True)
    
    return df

# %%
def upload_distributions(config_ind_path="config/config_ind.yaml"):
    df = get_distribution_ind_ids(config_ind_path)
    
    status_uploads = {}
    for dataset in catalog["dataset"]:
        for distribution in dataset["distribution"]:
            try:
                id_distribution = df.loc[catalog["title"], distribution["identifier"]]["id_distribution"]

                distribution_path = os.path.join(
                    DATASETS_DIR, dataset["identifier"], "{}.csv".format(distribution["identifier"]))

                # renamed_path = "/Users/abenassi/github/series-tiempo/catalogo/datos/datasets_ind/{}.csv".format(id_distribution)
                # shutil.copyfile(distribution_path, renamed_path)
                status = upload_distribution_to_ind(distribution_path, id_distribution, config_ind_path)
                
                if not status in status_uploads:
                    status_uploads[status] = []
                status_uploads[status].append({
                    "dataset_identifier": dataset["identifier"],
                    "distribution_identifier": distribution["identifier"],
                    "distribution_id_ind": id_distribution
                })
                print(dataset["identifier"], distribution["identifier"], id_distribution, status)

            except Exception as e:
                if not str(e) in status_uploads:
                    status_uploads[str(e)] = []
                status_uploads[str(e)].append({
                    "dataset_identifier": dataset["identifier"],
                    "distribution_identifier": distribution["identifier"],
                    "distribution_id_ind": id_distribution
                })
                print(dataset["identifier"], distribution["identifier"], id_distribution, e)
                continue

    return status_uploads

# %%
catalog = readers.read_catalog(test_catalog_json_path)
catalog_json_path
# Out:
# u'/Users/abenassi/github/series-tiempo/data/output/catalog/sspm/data.json'

# %%
print(upload_datajson_to_ind(test_catalog_json_path, "config/dev/config_ind.yaml"))
# Out:
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_bulkLoad_json&ID_USUARIO=n7/evuGi92aapvp5XgLnnQ==
# <webresult>
#   <result>OK</result>
#   <message>Job started</message>
#   <id>0aaaf9e5-a102-4063-a6ee-78dc26a74cd4</id>
# </webresult>
#
#
# <?xml version="1.0" encoding="UTF-8"?><html><body><jobstatus>
# <jobname></jobname>
# <id>0aaaf9e5-a102-4063-a6ee-78dc26a74cd4</id>
# <status_desc>Finished</status_desc>
# <error_desc></error_desc>
# <logging_string>&lt;![CDATA[...]]&gt;</logging_string>
# <first_log_line_nr>0</first_log_line_nr>
# <last_log_line_nr>19224183</last_log_line_nr>
# <result><lines_input>0</lines_input>
# <lines_output>0</lines_output>
# <lines_read>0</lines_read>
# <lines_written>0</lines_written>
# <lines_updated>0</lines_updated>
# <lines_rejected>0</lines_rejected>
# <lines_deleted>0</lines_deleted>
# <nr_errors>0</nr_errors>
# <nr_files_retrieved>0</nr_files_retrieved>
# <entry_nr>8</entry_nr>
# <result>Y</result>
# <exit_status>0</exit_status>
# <is_stopped>N</is_stopped>
# <log_channel_id>86c0b5c9-9156-467f-aeee-2b295974804e</log_channel_id>
# <log_text>2017/08/24 16:22:53 - Zip file - Total zipped files : 1
# 2017/08/24 16:22:33 - jb_bl_distribution_ins_upd - Starting entry [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:33 - tr_bl_distribution_ins_upd - Loading transformation from repository [tr_bl_distribution_ins_upd] in directory [/public/metadata-dinamica]
# 2017/08/24 16:22:33 - tr_bl_distribution_ins_upd - Dispatching started for transformation [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:33 - auth.0 - Finished processing (I=0, O=0, R=0, W=1, U=0, E=0)
# 2017/08/24 16:22:33 - Get rows from result.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:33 - in_distribution.0 - Finished reading query, closing connection.
# 2017/08/24 16:22:33 - in_distribution.0 - Finished processing (I=323, O=0, R=0, W=323, U=0, E=0)
# 2017/08/24 16:22:33 - lkp_distribution.0 - Finished processing (I=0, O=0, R=324, W=1, U=0, E=0)
# 2017/08/24 16:22:33 - uno auth.0 - Finished processing (I=0, O=0, R=2, W=1, U=0, E=0)
# 2017/08/24 16:22:33 - Write to log 2.0 -
# 2017/08/24 16:22:33 - Write to log 2.0 - ------------&gt; Linenr 1------------------------------
# 2017/08/24 16:22:33 - Write to log 2.0 - =========================
# 2017/08/24 16:22:33 - Write to log 2.0 -
# 2017/08/24 16:22:33 - Write to log 2.0 -
# 2017/08/24 16:22:33 - Write to log 2.0 - VOY A MODIFICAR UNA
# 2017/08/24 16:22:33 - Write to log 2.0 -    DISTRIBUCION
# 2017/08/24 16:22:33 - Write to log 2.0 -
# 2017/08/24 16:22:33 - Write to log 2.0 -
# 2017/08/24 16:22:33 - Write to log 2.0 - =========================
# 2017/08/24 16:22:33 - Write to log 2.0 -
# 2017/08/24 16:22:33 - Write to log 2.0 - header_value = Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJhcGlfYWRtaW4iLCJhdXRoIjoiUk9MRV9BRE1JTiIsImV4cCI6MTUwMzY4ODkzNH0.6TJMsWqHe4WuJ8Q3dD8mPVb4zgjuXQTmrgKk1p4O8Rv-mRalYf5RpR-o9iwWEMwnNYDx5iXxWZP3jO4Opik8Mg
# 2017/08/24 16:22:33 - Write to log 2.0 - distribution_js = {"descripcion":"Oferta y Demanda Globales por componente, a precios de comprador, en millones de pesos de 1993 y valores anuales desestacionalizados.","idDistribution":"1016","titulo":"Oferta y Demanda Globales a precios de 1993: Datos desestacionalizados en valores anuales [Base 1993]","frecuenciaActualizacionURL":"EVENTUAL","fields":[{"descripcion":null,"tipo":"DATE","unidades":null,"tipoEspecialDetalle":"R_P1Y","orden":1,"tipoEspecial":"INDICE_TIEMPO","nombre":"indice_tiempo","identificador":"1.1_IT_D_1993_A_13"}, {"descripcion":"PIB desestacionalizado, en millones de pesos de 1993 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":2,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_pbi","identificador":"1.1_OGP_D_1993_A_17"}, {"descripcion":"Importaciones desestacionalizadas, en millones de pesos de 1993 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":3,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_importacion","identificador":"1.1_OGI_D_1993_A_25"}, {"descripcion":"Exportaciones desestacionalizadas, en millones de pesos de 1993 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":4,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_exportacion","identificador":"1.1_DGE_D_1993_A_26"}, {"descripcion":"Inversion bruta interna fija desestacionalizada, en millones de pesos de 1993 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":5,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif","identificador":"1.1_DGI_D_1993_A_19"}, {"descripcion":"Consumo privado desestacionalizado, en millones de pesos de 1993 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":6,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_priv","identificador":"1.1_DGCP_D_1993_A_27"}, {"descripcion":"Consumo publico desestacionalizado, en millones de pesos de 1993 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":7,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_publico","identificador":"1.1_DGCP_D_1993_A_30"}],"id":"812537","urlAcceso":"http:\/\/www.minhacienda.gob.ar\/secretarias\/politica-economica\/programacion-macroeconomica\/","formatoArchivo":"CSV","urlDescarga":null,"idAutorReal":"10001","draft":"false","idDataset":20850,"fechaPublicacion":"2017-08-22T17:51:26.553961-03:00","identificador":"1.1"}
# 2017/08/24 16:22:33 - Write to log 2.0 -
# 2017/08/24 16:22:33 - Write to log 2.0 - ====================
# 2017/08/24 16:22:33 - pido token.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:33 - insert/update.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:33 - Dummy (do nothing) 4.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:33 - creo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:33 - remmplazo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:33 -  limpio token.0 - Finished processing (I=1, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:33 -  valor header.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:33 - Select values 2 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:33 - Write to log 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:36 - UPDATE.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:36 - jb_bl_distribution_ins_upd - Starting entry [Success]
# 2017/08/24 16:22:36 - jb_bl_distribution_ins_upd - Finished job entry [Success] (result=[true])
# 2017/08/24 16:22:36 - jb_bl_distribution_ins_upd - Finished job entry [tr_bl_distribution_ins_upd] (result=[true])
# 2017/08/24 16:22:36 - jb_bl_distribution_ins_upd - Starting entry [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:36 - tr_bl_distribution_ins_upd - Loading transformation from repository [tr_bl_distribution_ins_upd] in directory [/public/metadata-dinamica]
# 2017/08/24 16:22:36 - tr_bl_distribution_ins_upd - Dispatching started for transformation [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:36 - auth.0 - Finished processing (I=0, O=0, R=0, W=1, U=0, E=0)
# 2017/08/24 16:22:36 - Get rows from result.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:36 - in_distribution.0 - Finished reading query, closing connection.
# 2017/08/24 16:22:36 - in_distribution.0 - Finished processing (I=323, O=0, R=0, W=323, U=0, E=0)
# 2017/08/24 16:22:36 - lkp_distribution.0 - Finished processing (I=0, O=0, R=324, W=1, U=0, E=0)
# 2017/08/24 16:22:36 - uno auth.0 - Finished processing (I=0, O=0, R=2, W=1, U=0, E=0)
# 2017/08/24 16:22:36 - Write to log 2.0 -
# 2017/08/24 16:22:36 - Write to log 2.0 - ------------&gt; Linenr 1------------------------------
# 2017/08/24 16:22:36 - Write to log 2.0 - =========================
# 2017/08/24 16:22:36 - Write to log 2.0 -
# 2017/08/24 16:22:36 - Write to log 2.0 -
# 2017/08/24 16:22:36 - Write to log 2.0 - VOY A MODIFICAR UNA
# 2017/08/24 16:22:36 - Write to log 2.0 -    DISTRIBUCION
# 2017/08/24 16:22:36 - Write to log 2.0 -
# 2017/08/24 16:22:36 - Write to log 2.0 -
# 2017/08/24 16:22:36 - Write to log 2.0 - =========================
# 2017/08/24 16:22:36 - Write to log 2.0 -
# 2017/08/24 16:22:36 - Write to log 2.0 - header_value = Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJhcGlfYWRtaW4iLCJhdXRoIjoiUk9MRV9BRE1JTiIsImV4cCI6MTUwMzY4ODkzN30.7VvtBwhm4TuZf0dcZ3TfTHdKoE_uP1rb1qIpLZW3gw7i4NnWUzW8UMbje5tVtu9PliZIGwXbyspKT55IegIxyA
# 2017/08/24 16:22:36 - Write to log 2.0 - distribution_js = {"descripcion":"Oferta y Demanda Globales por componente, a precios de comprador, en millones de pesos de 1993 y valores anuales desestacionalizados.","idDistribution":"1017","titulo":"Oferta y Demanda Globales a precios de 1993: Datos desestacionalizados en valores trimestrales [Base 1993]","frecuenciaActualizacionURL":"EVENTUAL","fields":[{"descripcion":null,"tipo":"DATE","unidades":null,"tipoEspecialDetalle":"R_P3M","orden":1,"tipoEspecial":"INDICE_TIEMPO","nombre":"indice_tiempo","identificador":"1.2_IT_D_1993_T_13"}, {"descripcion":"PBI a precios de comprador, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":2,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_pbi","identificador":"1.2_OGP_D_1993_T_17"}, {"descripcion":"Importación a precios de comprador, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":3,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_importacion","identificador":"1.2_OGI_D_1993_T_25"}, {"descripcion":"Oferta global total a precios de comprador, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":4,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_exportacion","identificador":"1.2_DGE_D_1993_T_26"}, {"descripcion":"Consumo privado, en millones de pesos  de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":5,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif","identificador":"1.2_DGI_D_1993_T_19"}, {"descripcion":"Consumo publico, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":6,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_priv","identificador":"1.2_DGCP_D_1993_T_27"}, {"descripcion":"Inversion bruta interna fija, en millones de pesos de 1993  y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":7,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_publico","identificador":"1.2_DGCP_D_1993_T_30"}],"id":"812538","urlAcceso":"http:\/\/www.minhacienda.gob.ar\/secretarias\/politica-economica\/programacion-macroeconomica\/","formatoArchivo":"CSV","urlDescarga":null,"idAutorReal":"10001","draft":"false","idDataset":20850,"fechaPublicacion":"2017-08-22T17:51:26.553961-03:00","identificador":"1.2"}
# 2017/08/24 16:22:36 - Write to log 2.0 -
# 2017/08/24 16:22:36 - Write to log 2.0 - ====================
# 2017/08/24 16:22:36 - pido token.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:36 - insert/update.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:36 - Dummy (do nothing) 4.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:36 - creo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:36 - remmplazo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:36 -  limpio token.0 - Finished processing (I=1, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:36 -  valor header.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:36 - Select values 2 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:36 - Write to log 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:38 - UPDATE.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:38 - jb_bl_distribution_ins_upd - Starting entry [Success]
# 2017/08/24 16:22:38 - jb_bl_distribution_ins_upd - Finished job entry [Success] (result=[true])
# 2017/08/24 16:22:38 - jb_bl_distribution_ins_upd - Finished job entry [tr_bl_distribution_ins_upd] (result=[true])
# 2017/08/24 16:22:38 - jb_bl_distribution_ins_upd - Starting entry [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:38 - tr_bl_distribution_ins_upd - Loading transformation from repository [tr_bl_distribution_ins_upd] in directory [/public/metadata-dinamica]
# 2017/08/24 16:22:38 - tr_bl_distribution_ins_upd - Dispatching started for transformation [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:38 - Get rows from result.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:38 - auth.0 - Finished processing (I=0, O=0, R=0, W=1, U=0, E=0)
# 2017/08/24 16:22:38 - in_distribution.0 - Finished reading query, closing connection.
# 2017/08/24 16:22:38 - in_distribution.0 - Finished processing (I=323, O=0, R=0, W=323, U=0, E=0)
# 2017/08/24 16:22:38 - lkp_distribution.0 - Finished processing (I=0, O=0, R=324, W=1, U=0, E=0)
# 2017/08/24 16:22:39 - uno auth.0 - Finished processing (I=0, O=0, R=2, W=1, U=0, E=0)
# 2017/08/24 16:22:39 - Write to log 2.0 -
# 2017/08/24 16:22:39 - Write to log 2.0 - ------------&gt; Linenr 1------------------------------
# 2017/08/24 16:22:39 - Write to log 2.0 - =========================
# 2017/08/24 16:22:39 - Write to log 2.0 -
# 2017/08/24 16:22:39 - Write to log 2.0 -
# 2017/08/24 16:22:39 - Write to log 2.0 - VOY A MODIFICAR UNA
# 2017/08/24 16:22:39 - Write to log 2.0 -    DISTRIBUCION
# 2017/08/24 16:22:39 - Write to log 2.0 -
# 2017/08/24 16:22:39 - Write to log 2.0 -
# 2017/08/24 16:22:39 - Write to log 2.0 - =========================
# 2017/08/24 16:22:39 - Write to log 2.0 -
# 2017/08/24 16:22:39 - Write to log 2.0 - header_value = Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJhcGlfYWRtaW4iLCJhdXRoIjoiUk9MRV9BRE1JTiIsImV4cCI6MTUwMzY4ODkzOX0.C5P7r_VtClcDj7jLYDdqZ0jyny9CedwIl_SpVD3_Tt0nH2ruvWIQeM-Bkf856pK1m-_KdUDv45JOqJO9M78jmQ
# 2017/08/24 16:22:39 - Write to log 2.0 - distribution_js = {"descripcion":"Oferta y Demanda Globales por componente, a precios de comprador, en millones de pesos de 1993 y valores anuales.","idDistribution":"1039","titulo":"Oferta y Demanda Globales a precios de 1993: Valores anuales [Base 1993]","frecuenciaActualizacionURL":"EVENTUAL","fields":[{"descripcion":null,"tipo":"DATE","unidades":null,"tipoEspecialDetalle":"R_P1Y","orden":1,"tipoEspecial":"INDICE_TIEMPO","nombre":"indice_tiempo","identificador":"2.1_IT_1993_A_13"}, {"descripcion":"PBI a precios de comprador, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":2,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_pbi","identificador":"2.1_OGP_1993_A_17"}, {"descripcion":"Importación a precios de comprador, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":3,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_importacion","identificador":"2.1_OGI_1993_A_25"}, {"descripcion":"Oferta global total a precios de comprador, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":4,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_total","identificador":"2.1_OGT_1993_A_19"}, {"descripcion":"Consumo privado, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":5,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_priv","identificador":"2.1_DGCP_1993_A_27"}, {"descripcion":"Consumo publico, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":6,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_publico","identificador":"2.1_DGCP_1993_A_30"}, {"descripcion":"Inversion bruta interna fija, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":7,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif","identificador":"2.1_DGI_1993_A_19"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":8,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion","identificador":"2.1_DGIEDP_1993_A_45"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion nacional, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":9,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion_nacional","identificador":"2.1_DGIEDPN_1993_A_54"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion importado, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":10,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion_importado","identificador":"2.1_DGIEDPI_1993_A_55"}, {"descripcion":"Inversion bruta interna fija de maquinaria y equipo total, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":11,"tipoEspecial":"NO_APLICA","nombre":"dg_ibif_equipo_durable_prod_maquinaria_equipo_total","identificador":"2.1_DGIEDPMET_1993_A_69"}, {"descripcion":"Inversion bruta interna fija de maquinaria y equipo nacional, en millones de pesos de 1993 y valores anuales.","tipo":"NUMBER","unidades":"Millo ...
# 2017/08/24 16:22:39 - Write to log 2.0 -
# 2017/08/24 16:22:39 - Write to log 2.0 - ====================
# 2017/08/24 16:22:39 - pido token.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:39 - insert/update.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:39 - Dummy (do nothing) 4.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:39 - creo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:39 - remmplazo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:39 -  limpio token.0 - Finished processing (I=1, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:39 -  valor header.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:39 - Select values 2 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:39 - Write to log 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:41 - UPDATE.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:41 - jb_bl_distribution_ins_upd - Starting entry [Success]
# 2017/08/24 16:22:41 - jb_bl_distribution_ins_upd - Finished job entry [Success] (result=[true])
# 2017/08/24 16:22:41 - jb_bl_distribution_ins_upd - Finished job entry [tr_bl_distribution_ins_upd] (result=[true])
# 2017/08/24 16:22:41 - jb_bl_distribution_ins_upd - Starting entry [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:41 - tr_bl_distribution_ins_upd - Loading transformation from repository [tr_bl_distribution_ins_upd] in directory [/public/metadata-dinamica]
# 2017/08/24 16:22:41 - tr_bl_distribution_ins_upd - Dispatching started for transformation [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:41 - Get rows from result.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:41 - auth.0 - Finished processing (I=0, O=0, R=0, W=1, U=0, E=0)
# 2017/08/24 16:22:41 - in_distribution.0 - Finished reading query, closing connection.
# 2017/08/24 16:22:41 - in_distribution.0 - Finished processing (I=323, O=0, R=0, W=323, U=0, E=0)
# 2017/08/24 16:22:41 - lkp_distribution.0 - Finished processing (I=0, O=0, R=324, W=1, U=0, E=0)
# 2017/08/24 16:22:41 - uno auth.0 - Finished processing (I=0, O=0, R=2, W=1, U=0, E=0)
# 2017/08/24 16:22:41 - Write to log 2.0 -
# 2017/08/24 16:22:41 - Write to log 2.0 - ------------&gt; Linenr 1------------------------------
# 2017/08/24 16:22:41 - Write to log 2.0 - =========================
# 2017/08/24 16:22:41 - Write to log 2.0 -
# 2017/08/24 16:22:41 - Write to log 2.0 -
# 2017/08/24 16:22:41 - Write to log 2.0 - VOY A MODIFICAR UNA
# 2017/08/24 16:22:41 - Write to log 2.0 -    DISTRIBUCION
# 2017/08/24 16:22:41 - Write to log 2.0 -
# 2017/08/24 16:22:41 - Write to log 2.0 -
# 2017/08/24 16:22:41 - Write to log 2.0 - =========================
# 2017/08/24 16:22:41 - Write to log 2.0 -
# 2017/08/24 16:22:41 - Write to log 2.0 - header_value = Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJhcGlfYWRtaW4iLCJhdXRoIjoiUk9MRV9BRE1JTiIsImV4cCI6MTUwMzY4ODk0Mn0.lfwA9MKyQy2-kxoPC4vQwk_9lRkFNfeT7v97YqhmanleeuwGQfu74Bh0fThKffkeDNWRUexcCrfvHQyCbinRpg
# 2017/08/24 16:22:41 - Write to log 2.0 - distribution_js = {"descripcion":"Oferta y Demanda Globales por componente, a precios de comprador, en millones de pesos de 1993 y valores trimestrales.","idDistribution":"1040","titulo":"Oferta y Demanda Globales a precios de 1993: Valores trimestrales [Base 1993]","frecuenciaActualizacionURL":"EVENTUAL","fields":[{"descripcion":null,"tipo":"DATE","unidades":null,"tipoEspecialDetalle":"R_P3M","orden":1,"tipoEspecial":"INDICE_TIEMPO","nombre":"indice_tiempo","identificador":"2.2_IT_1993_T_13"}, {"descripcion":"PBI a precios de comprador, en millones de pesos de 1993 y valores trimestrales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":2,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_pbi","identificador":"2.2_OGP_1993_T_17"}, {"descripcion":"Importación a precios de comprador, en millones de pesos de 1993 y valores trimestrales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":3,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_importacion","identificador":"2.2_OGI_1993_T_25"}, {"descripcion":"Oferta global total a precios de comprador, en millones de pesos de 1993 y valores trimestrales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":4,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_total","identificador":"2.2_OGT_1993_T_19"}, {"descripcion":"Consumo privado, en millones de pesos de 1993 y valores trimestrales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":5,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_priv","identificador":"2.2_DGCP_1993_T_27"}, {"descripcion":"Consumo publico, en millones de pesos de 1993 y valores trimestrales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":6,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_publico","identificador":"2.2_DGCP_1993_T_30"}, {"descripcion":"Inversion bruta interna fija, en millones de pesos de 1993 y valores trimestrales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":7,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif","identificador":"2.2_DGI_1993_T_19"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion, en millones de pesos de 1993 y valores trimestrales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":8,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion","identificador":"2.2_DGIEDP_1993_T_45"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion nacional, en millones de pesos de 1993 y valores trimestrales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":9,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion_nacional","identificador":"2.2_DGIEDPN_1993_T_54"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion importado, en millones de pesos de 1993 y valores trimestrales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":10,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion_importado","identificador":"2.2_DGIEDPI_1993_T_55"}, {"descripcion":"Inversion bruta interna fija de maquinaria y equipo total, en millones de pesos de 1993 y valores trimestrales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 1993","tipoEspecialDetalle":"NO_APLICA","orden":11,"tipoEspecial":"NO_APLICA","nombre":"dg_ibif_equipo_durable_prod_maquinaria_equipo_total","identificador":"2.2_DGIEDPMET_1993_T_69"}, {"descripcion":"Inversion bruta interna fija de maquinaria y equipo nacional, en millones de pesos d ...
# 2017/08/24 16:22:41 - Write to log 2.0 -
# 2017/08/24 16:22:41 - Write to log 2.0 - ====================
# 2017/08/24 16:22:41 - pido token.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:41 - insert/update.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:41 - Dummy (do nothing) 4.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:41 - creo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:41 - remmplazo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:41 -  limpio token.0 - Finished processing (I=1, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:41 -  valor header.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:41 - Select values 2 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:41 - Write to log 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:43 - UPDATE.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:43 - jb_bl_distribution_ins_upd - Starting entry [Success]
# 2017/08/24 16:22:43 - jb_bl_distribution_ins_upd - Finished job entry [Success] (result=[true])
# 2017/08/24 16:22:43 - jb_bl_distribution_ins_upd - Finished job entry [tr_bl_distribution_ins_upd] (result=[true])
# 2017/08/24 16:22:43 - jb_bl_distribution_ins_upd - Starting entry [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:43 - tr_bl_distribution_ins_upd - Loading transformation from repository [tr_bl_distribution_ins_upd] in directory [/public/metadata-dinamica]
# 2017/08/24 16:22:43 - tr_bl_distribution_ins_upd - Dispatching started for transformation [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:43 - Get rows from result.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:43 - auth.0 - Finished processing (I=0, O=0, R=0, W=1, U=0, E=0)
# 2017/08/24 16:22:43 - in_distribution.0 - Finished reading query, closing connection.
# 2017/08/24 16:22:43 - in_distribution.0 - Finished processing (I=323, O=0, R=0, W=323, U=0, E=0)
# 2017/08/24 16:22:43 - lkp_distribution.0 - Finished processing (I=0, O=0, R=324, W=1, U=0, E=0)
# 2017/08/24 16:22:44 - uno auth.0 - Finished processing (I=0, O=0, R=2, W=1, U=0, E=0)
# 2017/08/24 16:22:44 - Write to log 2.0 -
# 2017/08/24 16:22:44 - Write to log 2.0 - ------------&gt; Linenr 1------------------------------
# 2017/08/24 16:22:44 - Write to log 2.0 - =========================
# 2017/08/24 16:22:44 - Write to log 2.0 -
# 2017/08/24 16:22:44 - Write to log 2.0 -
# 2017/08/24 16:22:44 - Write to log 2.0 - VOY A MODIFICAR UNA
# 2017/08/24 16:22:44 - Write to log 2.0 -    DISTRIBUCION
# 2017/08/24 16:22:44 - Write to log 2.0 -
# 2017/08/24 16:22:44 - Write to log 2.0 -
# 2017/08/24 16:22:44 - Write to log 2.0 - =========================
# 2017/08/24 16:22:44 - Write to log 2.0 -
# 2017/08/24 16:22:44 - Write to log 2.0 - header_value = Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJhcGlfYWRtaW4iLCJhdXRoIjoiUk9MRV9BRE1JTiIsImV4cCI6MTUwMzY4ODk0NH0.bVL0Ng_ZpD93iVn8glqmD_AmbsH2tKoCtLIyrm2N0slweee2a3ntjx3L3MfoatFaIXf1QCvvO6SLnX98u2ho7w
# 2017/08/24 16:22:44 - Write to log 2.0 - distribution_js = {"descripcion":"Oferta y Demanda Globales por componente, a precios de comprador, en millones de pesos de 1993 y valores anuales.","idDistribution":"1041","titulo":"Oferta y Demanda Globales a precios corrientes: Valores anuales [Base 1993]","frecuenciaActualizacionURL":"EVENTUAL","fields":[{"descripcion":null,"tipo":"DATE","unidades":null,"tipoEspecialDetalle":"R_P1Y","orden":1,"tipoEspecial":"INDICE_TIEMPO","nombre":"indice_tiempo","identificador":"2.3_IT_1993_A_13"}, {"descripcion":"PBI a precios de comprador, en millones de pesos corrientes y valores anuales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":2,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_pbi","identificador":"2.3_OGP_1993_A_17"}, {"descripcion":"Importación a precios de comprador, en millones de pesos corrientes y valores anuales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":3,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_importacion","identificador":"2.3_OGI_1993_A_25"}, {"descripcion":"Oferta global total a precios de comprador, en millones de pesos corrientes y valores anuales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":4,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_total","identificador":"2.3_OGT_1993_A_19"}, {"descripcion":"Consumo privado, en millones de pesos corrientes y valores anuales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":5,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_priv","identificador":"2.3_DGCP_1993_A_27"}, {"descripcion":"Consumo publico, en millones de pesos corrientes y valores anuales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":6,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_publico","identificador":"2.3_DGCP_1993_A_30"}, {"descripcion":"Inversion bruta interna fija, en millones de pesos corrientes y valores anuales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":7,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif","identificador":"2.3_DGI_1993_A_19"}, {"descripcion":"Inversion bruta interna fija en construccion, en millones de pesos corrientes y valores anuales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":8,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_construccion","identificador":"2.3_DGIC_1993_A_32"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion, en millones de pesos corrientes y valores anuales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":9,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion","identificador":"2.3_DGIEDP_1993_A_45"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion nacional, en millones de pesos corrientes y valores anuales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":10,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion_nacional","identificador":"2.3_DGIEDPN_1993_A_54"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion importado, en millones de pesos corrientes y valores anuales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":11,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion_importado","identificador":"2.3_DGIEDPI_1993_A_55"}, {"descripcion":"Inversion bruta interna fija de de equipos durables de produccion y maquinaria, en millones de pesos corrientes y valores anuales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDeta ...
# 2017/08/24 16:22:44 - Write to log 2.0 -
# 2017/08/24 16:22:44 - Write to log 2.0 - ====================
# 2017/08/24 16:22:44 - pido token.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:44 - insert/update.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:44 - Dummy (do nothing) 4.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:44 - creo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:44 - remmplazo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:44 -  limpio token.0 - Finished processing (I=1, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:44 -  valor header.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:44 - Select values 2 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:44 - Write to log 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - UPDATE.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - jb_bl_distribution_ins_upd - Starting entry [Success]
# 2017/08/24 16:22:46 - jb_bl_distribution_ins_upd - Finished job entry [Success] (result=[true])
# 2017/08/24 16:22:46 - jb_bl_distribution_ins_upd - Finished job entry [tr_bl_distribution_ins_upd] (result=[true])
# 2017/08/24 16:22:46 - jb_bl_distribution_ins_upd - Starting entry [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:46 - tr_bl_distribution_ins_upd - Loading transformation from repository [tr_bl_distribution_ins_upd] in directory [/public/metadata-dinamica]
# 2017/08/24 16:22:46 - tr_bl_distribution_ins_upd - Dispatching started for transformation [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:46 - Get rows from result.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - auth.0 - Finished processing (I=0, O=0, R=0, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - in_distribution.0 - Finished reading query, closing connection.
# 2017/08/24 16:22:46 - in_distribution.0 - Finished processing (I=323, O=0, R=0, W=323, U=0, E=0)
# 2017/08/24 16:22:46 - lkp_distribution.0 - Finished processing (I=0, O=0, R=324, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - uno auth.0 - Finished processing (I=0, O=0, R=2, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - Write to log 2.0 -
# 2017/08/24 16:22:46 - Write to log 2.0 - ------------&gt; Linenr 1------------------------------
# 2017/08/24 16:22:46 - Write to log 2.0 - =========================
# 2017/08/24 16:22:46 - Write to log 2.0 -
# 2017/08/24 16:22:46 - Write to log 2.0 -
# 2017/08/24 16:22:46 - Write to log 2.0 - VOY A MODIFICAR UNA
# 2017/08/24 16:22:46 - Write to log 2.0 -    DISTRIBUCION
# 2017/08/24 16:22:46 - Write to log 2.0 -
# 2017/08/24 16:22:46 - Write to log 2.0 -
# 2017/08/24 16:22:46 - Write to log 2.0 - =========================
# 2017/08/24 16:22:46 - Write to log 2.0 -
# 2017/08/24 16:22:46 - Write to log 2.0 - header_value = Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJhcGlfYWRtaW4iLCJhdXRoIjoiUk9MRV9BRE1JTiIsImV4cCI6MTUwMzY4ODk0N30.RTi8lMBDFzonuCSmA1Oi3uhBkZaS4LWBy4ZUqeTORRIflLGabpLhrRWRkF7L-Lxc8OV4qDsM01abqAEMrhJ0Kw
# 2017/08/24 16:22:46 - Write to log 2.0 - distribution_js = {"descripcion":"Oferta y Demanda Globales por componente, a precios de comprador, en millones de pesos de 1993 y valores trimestrales.","idDistribution":"1042","titulo":"Oferta y Demanda Globales a precios corrientes: Valores trimestrales [Base 1993]","frecuenciaActualizacionURL":"EVENTUAL","fields":[{"descripcion":null,"tipo":"DATE","unidades":null,"tipoEspecialDetalle":"R_P3M","orden":1,"tipoEspecial":"INDICE_TIEMPO","nombre":"indice_tiempo","identificador":"2.4_IT_1993_T_13"}, {"descripcion":"PBI a precios de comprador, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":2,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_pbi","identificador":"2.4_OGP_1993_T_17"}, {"descripcion":"Importación a precios de comprador, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":3,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_importacion","identificador":"2.4_OGI_1993_T_25"}, {"descripcion":"Oferta global total a precios de comprador, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":4,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_total","identificador":"2.4_OGT_1993_T_19"}, {"descripcion":"Consumo privado, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":5,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_priv","identificador":"2.4_DGCP_1993_T_27"}, {"descripcion":"Consumo publico, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":6,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_publico","identificador":"2.4_DGCP_1993_T_30"}, {"descripcion":"Inversion bruta interna fija, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":7,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif","identificador":"2.4_DGI_1993_T_19"}, {"descripcion":"Inversion bruta interna fija en construccion, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":8,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_construccion","identificador":"2.4_DGIC_1993_T_32"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":9,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion","identificador":"2.4_DGIEDP_1993_T_45"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion nacional, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":10,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion_nacional","identificador":"2.4_DGIEDPN_1993_T_54"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion importado, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":11,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion_importado","identificador":"2.4_DGIEDPI_1993_T_55"}, {"descripcion":"Inversion bruta interna fija de de equipos durables de produccion y maquinaria, en millones de pesos corrientes y valores trimestrales [Base 1993]." ...
# 2017/08/24 16:22:46 - Write to log 2.0 -
# 2017/08/24 16:22:46 - Write to log 2.0 - ====================
# 2017/08/24 16:22:46 - pido token.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - insert/update.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - Dummy (do nothing) 4.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - creo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - remmplazo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 -  limpio token.0 - Finished processing (I=1, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 -  valor header.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - Select values 2 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - Write to log 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:48 - UPDATE.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:48 - jb_bl_distribution_ins_upd - Starting entry [Success]
# 2017/08/24 16:22:48 - jb_bl_distribution_ins_upd - Finished job entry [Success] (result=[true])
# 2017/08/24 16:22:48 - jb_bl_distribution_ins_upd - Finished job entry [tr_bl_distribution_ins_upd] (result=[true])
# 2017/08/24 16:22:48 - jb_bl_distribution_ins_upd - Starting entry [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:48 - tr_bl_distribution_ins_upd - Loading transformation from repository [tr_bl_distribution_ins_upd] in directory [/public/metadata-dinamica]
# 2017/08/24 16:22:48 - tr_bl_distribution_ins_upd - Dispatching started for transformation [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:48 - auth.0 - Finished processing (I=0, O=0, R=0, W=1, U=0, E=0)
# 2017/08/24 16:22:48 - Get rows from result.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:48 - in_distribution.0 - Finished reading query, closing connection.
# 2017/08/24 16:22:48 - in_distribution.0 - Finished processing (I=323, O=0, R=0, W=323, U=0, E=0)
# 2017/08/24 16:22:49 - lkp_distribution.0 - Finished processing (I=0, O=0, R=324, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - uno auth.0 - Finished processing (I=0, O=0, R=2, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 - ------------&gt; Linenr 1------------------------------
# 2017/08/24 16:22:49 - Write to log 2.0 - =========================
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 - VOY A MODIFICAR UNA
# 2017/08/24 16:22:49 - Write to log 2.0 -    DISTRIBUCION
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 - =========================
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 - header_value = Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJhcGlfYWRtaW4iLCJhdXRoIjoiUk9MRV9BRE1JTiIsImV4cCI6MTUwMzY4ODk0OX0.JG6OJrmMLtcDmnYJchO0CfoUQeuUs3n-WWjf_yv-XQhs1EDcrWoFFlh3dUpgrFgTGGlLPNeEpb12rnE5gzJWmw
# 2017/08/24 16:22:49 - Write to log 2.0 - distribution_js = {"descripcion":"Oferta y Demanda Globales por componente, a precios de comprador, en millones de pesos de 2004 y valores anuales desestacionalizados.","idDistribution":"1063","titulo":"Oferta y Demanda Globales a precios de 2004: Datos desestacionalizados en valores anuales [Base 2004]","frecuenciaActualizacionURL":"EVENTUAL","fields":[{"descripcion":null,"tipo":"DATE","unidades":null,"tipoEspecialDetalle":"R_P1Y","orden":1,"tipoEspecial":"INDICE_TIEMPO","nombre":"indice_tiempo","identificador":"3.1_IT_D_2004_A_13"}, {"descripcion":"PIB desestacionalizado, en millones de pesos de 2004 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":2,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_pbi","identificador":"3.1_OGP_D_2004_A_17"}, {"descripcion":"Importaciones desestacionalizadas, en millones de pesos de 2004 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":3,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_importacion","identificador":"3.1_OGI_D_2004_A_25"}, {"descripcion":"Exportaciones desestacionalizadas, en millones de pesos de 2004 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":4,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_exportacion","identificador":"3.1_DGE_D_2004_A_26"}, {"descripcion":"Inversion bruta interna fija desestacionalizada, en millones de pesos de 2004 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":5,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif","identificador":"3.1_DGI_D_2004_A_19"}, {"descripcion":"Consumo privado desestacionalizado, en millones de pesos de 2004 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":6,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_priv","identificador":"3.1_DGCP_D_2004_A_27"}, {"descripcion":"Consumo publico desestacionalizado, en millones de pesos de 2004 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":7,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_publico","identificador":"3.1_DGCP_D_2004_A_30"}],"id":"861585","urlAcceso":"http:\/\/www.minhacienda.gob.ar\/secretarias\/politica-economica\/programacion-macroeconomica\/","formatoArchivo":"CSV","urlDescarga":null,"idAutorReal":"10001","draft":"false","idDataset":20852,"fechaPublicacion":"2017-08-22T17:51:26.553961-03:00","identificador":"3.1"}
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 - ====================
# 2017/08/24 16:22:49 - pido token.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - insert/update.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - Dummy (do nothing) 4.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - creo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - remmplazo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 -  limpio token.0 - Finished processing (I=1, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 -  valor header.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - Select values 2 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - Write to log 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - UPDATE.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - jb_bl_distribution_ins_upd - Starting entry [Success]
# 2017/08/24 16:22:51 - jb_bl_distribution_ins_upd - Finished job entry [Success] (result=[true])
# 2017/08/24 16:22:51 - jb_bl_distribution_ins_upd - Finished job entry [tr_bl_distribution_ins_upd] (result=[true])
# 2017/08/24 16:22:51 - jb_bl_distribution_ins_upd - Starting entry [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:51 - tr_bl_distribution_ins_upd - Loading transformation from repository [tr_bl_distribution_ins_upd] in directory [/public/metadata-dinamica]
# 2017/08/24 16:22:51 - tr_bl_distribution_ins_upd - Dispatching started for transformation [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:51 - auth.0 - Finished processing (I=0, O=0, R=0, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - Get rows from result.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - in_distribution.0 - Finished reading query, closing connection.
# 2017/08/24 16:22:51 - in_distribution.0 - Finished processing (I=323, O=0, R=0, W=323, U=0, E=0)
# 2017/08/24 16:22:51 - lkp_distribution.0 - Finished processing (I=0, O=0, R=324, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - uno auth.0 - Finished processing (I=0, O=0, R=2, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - Write to log 2.0 -
# 2017/08/24 16:22:51 - Write to log 2.0 - ------------&gt; Linenr 1------------------------------
# ...
# 2017/08/24 16:22:46 - Write to log 2.0 - distribution_js = {"descripcion":"Oferta y Demanda Globales por componente, a precios de comprador, en millones de pesos de 1993 y valores trimestrales.","idDistribution":"1042","titulo":"Oferta y Demanda Globales a precios corrientes: Valores trimestrales [Base 1993]","frecuenciaActualizacionURL":"EVENTUAL","fields":[{"descripcion":null,"tipo":"DATE","unidades":null,"tipoEspecialDetalle":"R_P3M","orden":1,"tipoEspecial":"INDICE_TIEMPO","nombre":"indice_tiempo","identificador":"2.4_IT_1993_T_13"}, {"descripcion":"PBI a precios de comprador, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":2,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_pbi","identificador":"2.4_OGP_1993_T_17"}, {"descripcion":"Importación a precios de comprador, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":3,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_importacion","identificador":"2.4_OGI_1993_T_25"}, {"descripcion":"Oferta global total a precios de comprador, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":4,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_total","identificador":"2.4_OGT_1993_T_19"}, {"descripcion":"Consumo privado, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":5,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_priv","identificador":"2.4_DGCP_1993_T_27"}, {"descripcion":"Consumo publico, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":6,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_publico","identificador":"2.4_DGCP_1993_T_30"}, {"descripcion":"Inversion bruta interna fija, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":7,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif","identificador":"2.4_DGI_1993_T_19"}, {"descripcion":"Inversion bruta interna fija en construccion, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":8,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_construccion","identificador":"2.4_DGIC_1993_T_32"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":9,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion","identificador":"2.4_DGIEDP_1993_T_45"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion nacional, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":10,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion_nacional","identificador":"2.4_DGIEDPN_1993_T_54"}, {"descripcion":"Inversion bruta interna fija de equipo durable de produccion importado, en millones de pesos corrientes y valores trimestrales [Base 1993].","tipo":"NUMBER","unidades":"Millones de pesos","tipoEspecialDetalle":"NO_APLICA","orden":11,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif_equipo_durable_produccion_importado","identificador":"2.4_DGIEDPI_1993_T_55"}, {"descripcion":"Inversion bruta interna fija de de equipos durables de produccion y maquinaria, en millones de pesos corrientes y valores trimestrales [Base 1993]." ...
# 2017/08/24 16:22:46 - Write to log 2.0 -
# 2017/08/24 16:22:46 - Write to log 2.0 - ====================
# 2017/08/24 16:22:46 - pido token.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - insert/update.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - Dummy (do nothing) 4.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - creo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - remmplazo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 -  limpio token.0 - Finished processing (I=1, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 -  valor header.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - Select values 2 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:46 - Write to log 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:48 - UPDATE.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:48 - tr_bl_distribution_ins_upd - Loading transformation from repository [tr_bl_distribution_ins_upd] in directory [/public/metadata-dinamica]
# 2017/08/24 16:22:48 - tr_bl_distribution_ins_upd - Dispatching started for transformation [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:48 - auth.0 - Finished processing (I=0, O=0, R=0, W=1, U=0, E=0)
# 2017/08/24 16:22:48 - Get rows from result.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:48 - in_distribution.0 - Finished reading query, closing connection.
# 2017/08/24 16:22:48 - in_distribution.0 - Finished processing (I=323, O=0, R=0, W=323, U=0, E=0)
# 2017/08/24 16:22:49 - lkp_distribution.0 - Finished processing (I=0, O=0, R=324, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - uno auth.0 - Finished processing (I=0, O=0, R=2, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 - ------------&gt; Linenr 1------------------------------
# 2017/08/24 16:22:49 - Write to log 2.0 - =========================
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 - VOY A MODIFICAR UNA
# 2017/08/24 16:22:49 - Write to log 2.0 -    DISTRIBUCION
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 - =========================
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 - header_value = Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJhcGlfYWRtaW4iLCJhdXRoIjoiUk9MRV9BRE1JTiIsImV4cCI6MTUwMzY4ODk0OX0.JG6OJrmMLtcDmnYJchO0CfoUQeuUs3n-WWjf_yv-XQhs1EDcrWoFFlh3dUpgrFgTGGlLPNeEpb12rnE5gzJWmw
# 2017/08/24 16:22:49 - Write to log 2.0 - distribution_js = {"descripcion":"Oferta y Demanda Globales por componente, a precios de comprador, en millones de pesos de 2004 y valores anuales desestacionalizados.","idDistribution":"1063","titulo":"Oferta y Demanda Globales a precios de 2004: Datos desestacionalizados en valores anuales [Base 2004]","frecuenciaActualizacionURL":"EVENTUAL","fields":[{"descripcion":null,"tipo":"DATE","unidades":null,"tipoEspecialDetalle":"R_P1Y","orden":1,"tipoEspecial":"INDICE_TIEMPO","nombre":"indice_tiempo","identificador":"3.1_IT_D_2004_A_13"}, {"descripcion":"PIB desestacionalizado, en millones de pesos de 2004 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":2,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_pbi","identificador":"3.1_OGP_D_2004_A_17"}, {"descripcion":"Importaciones desestacionalizadas, en millones de pesos de 2004 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":3,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_importacion","identificador":"3.1_OGI_D_2004_A_25"}, {"descripcion":"Exportaciones desestacionalizadas, en millones de pesos de 2004 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":4,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_exportacion","identificador":"3.1_DGE_D_2004_A_26"}, {"descripcion":"Inversion bruta interna fija desestacionalizada, en millones de pesos de 2004 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":5,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif","identificador":"3.1_DGI_D_2004_A_19"}, {"descripcion":"Consumo privado desestacionalizado, en millones de pesos de 2004 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":6,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_priv","identificador":"3.1_DGCP_D_2004_A_27"}, {"descripcion":"Consumo publico desestacionalizado, en millones de pesos de 2004 y valores trimestrales","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":7,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_publico","identificador":"3.1_DGCP_D_2004_A_30"}],"id":"861585","urlAcceso":"http:\/\/www.minhacienda.gob.ar\/secretarias\/politica-economica\/programacion-macroeconomica\/","formatoArchivo":"CSV","urlDescarga":null,"idAutorReal":"10001","draft":"false","idDataset":20852,"fechaPublicacion":"2017-08-22T17:51:26.553961-03:00","identificador":"3.1"}
# 2017/08/24 16:22:49 - Write to log 2.0 -
# 2017/08/24 16:22:49 - Write to log 2.0 - ====================
# 2017/08/24 16:22:49 - pido token.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - insert/update.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - Dummy (do nothing) 4.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - creo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - remmplazo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 -  limpio token.0 - Finished processing (I=1, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 -  valor header.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - Select values 2 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:49 - Write to log 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - UPDATE.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - tr_bl_distribution_ins_upd - Loading transformation from repository [tr_bl_distribution_ins_upd] in directory [/public/metadata-dinamica]
# 2017/08/24 16:22:51 - tr_bl_distribution_ins_upd - Dispatching started for transformation [tr_bl_distribution_ins_upd]
# 2017/08/24 16:22:51 - auth.0 - Finished processing (I=0, O=0, R=0, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - Get rows from result.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - in_distribution.0 - Finished reading query, closing connection.
# 2017/08/24 16:22:51 - in_distribution.0 - Finished processing (I=323, O=0, R=0, W=323, U=0, E=0)
# 2017/08/24 16:22:51 - lkp_distribution.0 - Finished processing (I=0, O=0, R=324, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - uno auth.0 - Finished processing (I=0, O=0, R=2, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - Write to log 2.0 -
# 2017/08/24 16:22:51 - Write to log 2.0 - ------------&gt; Linenr 1------------------------------
# 2017/08/24 16:22:51 - Write to log 2.0 - =========================
# 2017/08/24 16:22:51 - Write to log 2.0 -
# 2017/08/24 16:22:51 - Write to log 2.0 -
# 2017/08/24 16:22:51 - Write to log 2.0 - VOY A MODIFICAR UNA
# 2017/08/24 16:22:51 - Write to log 2.0 -    DISTRIBUCION
# 2017/08/24 16:22:51 - Write to log 2.0 -
# 2017/08/24 16:22:51 - Write to log 2.0 -
# 2017/08/24 16:22:51 - Write to log 2.0 - =========================
# 2017/08/24 16:22:51 - Write to log 2.0 -
# 2017/08/24 16:22:51 - Write to log 2.0 - header_value = Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJhcGlfYWRtaW4iLCJhdXRoIjoiUk9MRV9BRE1JTiIsImV4cCI6MTUwMzY4ODk1Mn0.3vrt9QiyYlyXOWYf4NCzYXCr67YC895TevrxflqR_dRxT790wDUAZqeK7hcfqnEaP8QICriwpoWPhCMAOfX_5w
# 2017/08/24 16:22:51 - Write to log 2.0 - distribution_js = {"descripcion":"Oferta y Demanda Globales por componente, a precios de comprador, en millones de pesos de 2004 y valores trimestral desestacionalizados.","idDistribution":"1064","titulo":"Oferta y Demanda Globales a precios de 2004: Datos desestacionalizados en valores trimestral [Base 2004]","frecuenciaActualizacionURL":"EVENTUAL","fields":[{"descripcion":null,"tipo":"DATE","unidades":null,"tipoEspecialDetalle":"R_P3M","orden":1,"tipoEspecial":"INDICE_TIEMPO","nombre":"indice_tiempo","identificador":"3.2_IT_D_2004_T_13"}, {"descripcion":"Oferta global total a precios de comprador, en millones de pesos de 2004 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":2,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_pbi","identificador":"3.2_OGP_D_2004_T_17"}, {"descripcion":"Importación a precios de comprador, en millones de pesos de 2004 y valores trimestrales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":3,"tipoEspecial":"NO_APLICA","nombre":"oferta_global_importacion","identificador":"3.2_OGI_D_2004_T_25"}, {"descripcion":"Exportación a precios de comprador, en millones de pesos de 2004 y valores trimestrales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":4,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_exportacion","identificador":"3.2_DGE_D_2004_T_26"}, {"descripcion":"Inversion bruta interna fija, en millones de pesos de 2004 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":5,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_ibif","identificador":"3.2_DGI_D_2004_T_19"}, {"descripcion":"Consumo privado, en millones de pesos de 2004 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":6,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_priv","identificador":"3.2_DGCP_D_2004_T_27"}, {"descripcion":"Consumo publico, en millones de pesos de 2004 y valores anuales.","tipo":"NUMBER","unidades":"Millones de pesos a precios de 2004","tipoEspecialDetalle":"NO_APLICA","orden":7,"tipoEspecial":"NO_APLICA","nombre":"demanda_global_consumo_publico","identificador":"3.2_DGCP_D_2004_T_30"}],"id":"861586","urlAcceso":"http:\/\/www.minhacienda.gob.ar\/secretarias\/politica-economica\/programacion-macroeconomica\/","formatoArchivo":"CSV","urlDescarga":null,"idAutorReal":"10001","draft":"false","idDataset":20852,"fechaPublicacion":"2017-08-22T17:51:26.553961-03:00","identificador":"3.2"}
# 2017/08/24 16:22:51 - Write to log 2.0 -
# 2017/08/24 16:22:51 - Write to log 2.0 - ====================
# 2017/08/24 16:22:51 - pido token.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - insert/update.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - Dummy (do nothing) 4.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - creo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - remmplazo ids.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 -  limpio token.0 - Finished processing (I=1, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 -  valor header.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - Select values 2 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:51 - Write to log 2.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/24 16:22:53 - UPDATE.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# null</log_text>
# </result></jobstatus>
# </body></html>

# %%
print(upload_datajson_to_ind(test_catalog_json_path, "config/config_ind.yaml"))
# Out:
# http://192.168.150.221:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_bulkLoad_json&ID_USUARIO=n7/evuGi92aapvp5XgLnnQ==
# <webresult>
#   <result>OK</result>
#   <message>Job started</message>
#   <id>cb11aefd-a4c0-4a4b-8d03-758ca24be6a6</id>
# </webresult>
#
#
# <?xml version="1.0" encoding="UTF-8"?><html><body><jobstatus>
# <jobname></jobname>
# <id>cb11aefd-a4c0-4a4b-8d03-758ca24be6a6</id>
# <status_desc>Stopped (with errors)</status_desc>
# <error_desc></error_desc>
# <logging_string>&lt;![CDATA[...]]&gt;</logging_string>
# <first_log_line_nr>0</first_log_line_nr>
# <last_log_line_nr>499</last_log_line_nr>
# <result><lines_input>0</lines_input>
# <lines_output>0</lines_output>
# <lines_read>0</lines_read>
# <lines_written>0</lines_written>
# <lines_updated>0</lines_updated>
# <lines_rejected>0</lines_rejected>
# <lines_deleted>0</lines_deleted>
# <nr_errors>1</nr_errors>
# <nr_files_retrieved>0</nr_files_retrieved>
# <entry_nr>8</entry_nr>
# <result>N</result>
# <exit_status>0</exit_status>
# <is_stopped>N</is_stopped>
# <log_channel_id>32899287-b331-491d-930d-ced41c1df359</log_channel_id>
# <log_text>2017/08/24 16:30:26 - Abort job - ERROR (version 6.1.0.10-322, build 1 from 2017-01-20 12.32.47 by buildguy) : Aborting job.
# 2017/08/24 16:30:23 - Zip file - ERROR (version 6.1.0.10-322, build 1 from 2017-01-20 12.32.47 by buildguy) : Source folder/file [/home/abenassi/data.json] can not be found!
# 2017/08/24 16:30:22 - tr_bl_genera_distribution - Loading transformation from repository [tr_bl_genera_distribution] in directory [/public/metadata-dinamica]
# 2017/08/24 16:30:23 - tr_bl_genera_distribution - Dispatching started for transformation [tr_bl_genera_distribution]
# 2017/08/24 16:30:23 - in_dataset.0 - Finished reading query, closing connection.
# 2017/08/24 16:30:23 - in_dataset.0 - Finished processing (I=1, O=0, R=0, W=1, U=0, E=0)
# 2017/08/24 16:30:23 - lkp_catalog.0 - Finished processing (I=0, O=0, R=1, W=0, U=0, E=0)
# null</log_text>
# </result></jobstatus>
# </body></html>

# %%
# sube distribuciones
status_distributions_2 = upload_distributions("config/config_ind.yaml")
for key, value in status_distributions_2.iteritems():
    print(key, len(value))
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-35-80cdc3dbe144> in <module>()
#       1 # sube distribuciones
# ----> 2 status_distributions_2 = upload_distributions("config/config_ind.yaml")
#       3 for key, value in status_distributions_2.iteritems():
#       4     print(key, len(value))
#
# <ipython-input-28-de7651a67e2d> in upload_distributions(config_ind_path)
#       1 def upload_distributions(config_ind_path="config/config_ind.yaml"):
# ----> 2     df = get_distribution_ind_ids(config_ind_path)
#       3
#       4     status_uploads = {}
#       5     for dataset in catalog["dataset"]:
#
# <ipython-input-27-20c2ceb1ae2b> in get_distribution_ind_ids(config_ind_path)
#      23
#      24     index_cols = ["nombre", "identificador"]
# ---> 25     df_distribs = pd.read_sql_query(query, engine).dropna().sort_values(index_cols)
#      26     df = df_distribs.drop_duplicates(index_cols, keep="last").set_index(index_cols)
#      27     df.sort_index(level=index_cols, ascending=[1, 0], inplace=True)
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/pandas/io/sql.pyc in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330     return pandas_sql.read_query(
#     331         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 332         parse_dates=parse_dates, chunksize=chunksize)
#     333
#     334
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/pandas/io/sql.pyc in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1085         args = _convert_params(sql, params)
#    1086
# -> 1087         result = self.execute(*args)
#    1088         columns = result.keys()
#    1089
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/pandas/io/sql.pyc in execute(self, *args, **kwargs)
#     976     def execute(self, *args, **kwargs):
#     977         """Simple passthrough to SQLAlchemy connectable"""
# --> 978         return self.connectable.execute(*args, **kwargs)
#     979
#     980     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in execute(self, statement, *multiparams, **params)
#    2062
#    2063         connection = self.contextual_connect(close_with_result=True)
# -> 2064         return connection.execute(statement, *multiparams, **params)
#    2065
#    2066     def scalar(self, statement, *multiparams, **params):
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in execute(self, object, *multiparams, **params)
#     937         """
#     938         if isinstance(object, util.string_types[0]):
# --> 939             return self._execute_text(object, multiparams, params)
#     940         try:
#     941             meth = object._execute_on_connection
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in _execute_text(self, statement, multiparams, params)
#    1095             statement,
#    1096             parameters,
# -> 1097             statement, parameters
#    1098         )
#    1099         if self._has_events or self.engine._has_events:
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1187                 parameters,
#    1188                 cursor,
# -> 1189                 context)
#    1190
#    1191         if self._has_events or self.engine._has_events:
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1400                 util.raise_from_cause(
#    1401                     sqlalchemy_exception,
# -> 1402                     exc_info
#    1403                 )
#    1404             else:
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/sqlalchemy/util/compat.pyc in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1180                         statement,
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#    1184             self._handle_dbapi_exception(
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/sqlalchemy/engine/default.pyc in do_execute(self, cursor, statement, parameters, context)
#     468
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#     472     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.ProgrammingError) permission denied for relation distribution
#  [SQL: '\n        SELECT\n            ct.id_catalog, ct.nombre, ds.id_distribution, ds.identificador\n        FROM distribution ds\n            inner join dataset dt on (dt.id_dataset = ds.id_dataset)\n            inner join catalog ct on (dt.id_catalog= ct.id_catalog)\n        WHERE \n            ds.vigente = TRUE and \n            dt.vigente = TRUE and \n            ct.vigente = TRUE;\n    ']

# %%
# sube distribuciones
status_distributions = upload_distributions("config/config_ind.yaml")
for key, value in status_distributions.iteritems():
    print(key, len(value))
# Out:
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/1/1.1.csv / Remote: /home/abenassi/1016.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1016&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'1', u'1.1', 1016, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/1/1.2.csv / Remote: /home/abenassi/1017.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1017&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'1', u'1.2', 1017, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/2/2.1.csv / Remote: /home/abenassi/1039.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1039&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'2', u'2.1', 1039, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/2/2.2.csv / Remote: /home/abenassi/1040.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1040&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'2', u'2.2', 1040, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/2/2.3.csv / Remote: /home/abenassi/1041.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1041&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'2', u'2.3', 1041, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/2/2.4.csv / Remote: /home/abenassi/1042.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1042&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'2', u'2.4', 1042, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/3/3.1.csv / Remote: /home/abenassi/1063.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1063&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'3', u'3.1', 1063, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/3/3.2.csv / Remote: /home/abenassi/1064.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1064&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'3', u'3.2', 1064, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/4/4.1.csv / Remote: /home/abenassi/1078.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1078&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'4', u'4.1', 1078, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/4/4.2.csv / Remote: /home/abenassi/1079.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1079&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'4', u'4.2', 1079, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/4/4.3.csv / Remote: /home/abenassi/1080.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1080&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'4', u'4.3', 1080, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/4/4.4.csv / Remote: /home/abenassi/1081.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1081&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'4', u'4.4', 1081, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/5/5.1.csv / Remote: /home/abenassi/1082.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1082&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'5', u'5.1', 1082, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/5/5.2.csv / Remote: /home/abenassi/1083.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1083&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'5', u'5.2', 1083, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/6/6.1.csv / Remote: /home/abenassi/1084.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1084&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'6', u'6.1', 1084, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/6/6.2.csv / Remote: /home/abenassi/1085.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1085&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'6', u'6.2', 1085, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/7/7.1.csv / Remote: /home/abenassi/1086.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1086&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'7', u'7.1', 1086, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/7/7.2.csv / Remote: /home/abenassi/1087.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1087&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'7', u'7.2', 1087, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/8/8.1.csv / Remote: /home/abenassi/1088.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1088&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'8', u'8.1', 1088, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/8/8.2.csv / Remote: /home/abenassi/1089.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1089&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'8', u'8.2', 1089, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/9/9.1.csv / Remote: /home/abenassi/1090.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1090&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'9', u'9.1', 1090, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/9/9.2.csv / Remote: /home/abenassi/1091.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1091&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'9', u'9.2', 1091, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/10/10.1.csv / Remote: /home/abenassi/1018.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1018&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'10', u'10.1', 1018, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/10/10.2.csv / Remote: /home/abenassi/1019.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1019&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'10', u'10.2', 1019, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/10/10.3.csv / Remote: /home/abenassi/1020.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1020&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'10', u'10.3', 1020, u'Finished')
# (u'11', u'11.1', 1020, KeyError((u'Datos Programaci\xf3n Macroecon\xf3mica', u'11.1'),))
# (u'11', u'11.2', 1020, KeyError((u'Datos Programaci\xf3n Macroecon\xf3mica', u'11.2'),))
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/11/11.3.csv / Remote: /home/abenassi/1021.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1021&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'11', u'11.3', 1021, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/12/12.1.csv / Remote: /home/abenassi/1022.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1022&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'12', u'12.1', 1022, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/12/12.2.csv / Remote: /home/abenassi/1023.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1023&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'12', u'12.2', 1023, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/12/12.3.csv / Remote: /home/abenassi/1024.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1024&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'12', u'12.3', 1024, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/13/13.1.csv / Remote: /home/abenassi/1025.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1025&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'13', u'13.1', 1025, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/13/13.2.csv / Remote: /home/abenassi/1026.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1026&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'13', u'13.2', 1026, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/13/13.3.csv / Remote: /home/abenassi/1027.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1027&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'13', u'13.3', 1027, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/14/14.2.csv / Remote: /home/abenassi/1028.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1028&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'14', u'14.2', 1028, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/15/15.1.csv / Remote: /home/abenassi/1029.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1029&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'15', u'15.1', 1029, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/15/15.2.csv / Remote: /home/abenassi/1030.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1030&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'15', u'15.2', 1030, u'Finished')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/16/16.1.csv / Remote: /home/abenassi/1031.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1031&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'16', u'16.1', 1031, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/16/16.2.csv / Remote: /home/abenassi/1032.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1032&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'16', u'16.2', 1032, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/17/17.1.csv / Remote: /home/abenassi/1033.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1033&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'17', u'17.1', 1033, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/17/17.2.csv / Remote: /home/abenassi/1034.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1034&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'17', u'17.2', 1034, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/18/18.1.csv / Remote: /home/abenassi/1035.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1035&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'18', u'18.1', 1035, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/18/18.2.csv / Remote: /home/abenassi/1036.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1036&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'18', u'18.2', 1036, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/19/19.1.csv / Remote: /home/abenassi/1037.csv
# (u'19', u'19.1', 1037, OSError(2, 'No such file or directory'))
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/19/19.2.csv / Remote: /home/abenassi/1038.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1038&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'19', u'19.2', 1038, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/20/20.1.csv / Remote: /home/abenassi/1043.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1043&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'20', u'20.1', 1043, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/20/20.2.csv / Remote: /home/abenassi/1044.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1044&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'20', u'20.2', 1044, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/21/21.1.csv / Remote: /home/abenassi/1045.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1045&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'21', u'21.1', 1045, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/21/21.2.csv / Remote: /home/abenassi/1046.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1046&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'21', u'21.2', 1046, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/22/22.1.csv / Remote: /home/abenassi/1047.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1047&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'22', u'22.1', 1047, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/22/22.2.csv / Remote: /home/abenassi/1048.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1048&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'22', u'22.2', 1048, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/23/23.1.csv / Remote: /home/abenassi/1049.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1049&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'23', u'23.1', 1049, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/23/23.2.csv / Remote: /home/abenassi/1050.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1050&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'23', u'23.2', 1050, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/24/24.1.csv / Remote: /home/abenassi/1051.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1051&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'24', u'24.1', 1051, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/24/24.2.csv / Remote: /home/abenassi/1052.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1052&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'24', u'24.2', 1052, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/25/25.1.csv / Remote: /home/abenassi/1053.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1053&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'25', u'25.1', 1053, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/25/25.2.csv / Remote: /home/abenassi/1054.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1054&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'25', u'25.2', 1054, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/26/26.1.csv / Remote: /home/abenassi/1055.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1055&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'26', u'26.1', 1055, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/26/26.2.csv / Remote: /home/abenassi/1056.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1056&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'26', u'26.2', 1056, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/27/27.1.csv / Remote: /home/abenassi/1057.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1057&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'27', u'27.1', 1057, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/27/27.2.csv / Remote: /home/abenassi/1058.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1058&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'27', u'27.2', 1058, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/28/28.1.csv / Remote: /home/abenassi/1059.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1059&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'28', u'28.1', 1059, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/29/29.1.csv / Remote: /home/abenassi/1060.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1060&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'29', u'29.1', 1060, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/29/29.2.csv / Remote: /home/abenassi/1061.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1061&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'29', u'29.2', 1061, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/29/29.3.csv / Remote: /home/abenassi/1062.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1062&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'29', u'29.3', 1062, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/30/30.1.csv / Remote: /home/abenassi/1065.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1065&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'30', u'30.1', 1065, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/30/30.2.csv / Remote: /home/abenassi/1066.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1066&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'30', u'30.2', 1066, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/30/30.3.csv / Remote: /home/abenassi/1067.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1067&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'30', u'30.3', 1067, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/31/31.2.csv / Remote: /home/abenassi/1068.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1068&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'31', u'31.2', 1068, u'Halting')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/31/31.3.csv / Remote: /home/abenassi/1069.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1069&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'31', u'31.3', 1069, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/32/32.1.csv / Remote: /home/abenassi/1070.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1070&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'32', u'32.1', 1070, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/32/32.2.csv / Remote: /home/abenassi/1071.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1071&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'32', u'32.2', 1071, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/32/32.3.csv / Remote: /home/abenassi/1072.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1072&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'32', u'32.3', 1072, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/33/33.2.csv / Remote: /home/abenassi/1073.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1073&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'33', u'33.2', 1073, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/34/34.1.csv / Remote: /home/abenassi/1074.csv
# (u'34', u'34.1', 1074, OSError(2, 'No such file or directory'))
# (u'34', u'34.2', 1074, KeyError((u'Datos Programaci\xf3n Macroecon\xf3mica', u'34.2'),))
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/35/35.1.csv / Remote: /home/abenassi/1075.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1075&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'35', u'35.1', 1075, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/35/35.2.csv / Remote: /home/abenassi/1076.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1076&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'35', u'35.2', 1076, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/35/35.3.csv / Remote: /home/abenassi/1077.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1077&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'35', u'35.3', 1077, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/36/36.1.csv / Remote: /home/abenassi/1173.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1173&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'36', u'36.1', 1173, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/36/36.2.csv / Remote: /home/abenassi/1174.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1174&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'36', u'36.2', 1174, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/36/36.3.csv / Remote: /home/abenassi/1175.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1175&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'36', u'36.3', 1175, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/37/37.1.csv / Remote: /home/abenassi/1176.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1176&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'37', u'37.1', 1176, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/37/37.2.csv / Remote: /home/abenassi/1177.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1177&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'37', u'37.2', 1177, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/37/37.3.csv / Remote: /home/abenassi/1178.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1178&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'37', u'37.3', 1178, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/38/38.1.csv / Remote: /home/abenassi/1179.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1179&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'38', u'38.1', 1179, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/38/38.2.csv / Remote: /home/abenassi/1180.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1180&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'38', u'38.2', 1180, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/38/38.3.csv / Remote: /home/abenassi/1181.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1181&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'38', u'38.3', 1181, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/39/39.1.csv / Remote: /home/abenassi/1182.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1182&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'39', u'39.1', 1182, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/39/39.2.csv / Remote: /home/abenassi/1183.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1183&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'39', u'39.2', 1183, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/39/39.3.csv / Remote: /home/abenassi/1184.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1184&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'39', u'39.3', 1184, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/40/40.1.csv / Remote: /home/abenassi/1185.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1185&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'40', u'40.1', 1185, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/40/40.2.csv / Remote: /home/abenassi/1186.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1186&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'40', u'40.2', 1186, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/40/40.3.csv / Remote: /home/abenassi/1187.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1187&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'40', u'40.3', 1187, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/41/41.1.csv / Remote: /home/abenassi/1188.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1188&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'41', u'41.1', 1188, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/41/41.2.csv / Remote: /home/abenassi/1189.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1189&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'41', u'41.2', 1189, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/41/41.3.csv / Remote: /home/abenassi/1190.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1190&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'41', u'41.3', 1190, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/42/42.1.csv / Remote: /home/abenassi/1191.csv
# (u'42', u'42.1', 1191, OSError(2, 'No such file or directory'))
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/42/42.2.csv / Remote: /home/abenassi/1192.csv
# (u'42', u'42.2', 1192, OSError(2, 'No such file or directory'))
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/43/43.1.csv / Remote: /home/abenassi/1193.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1193&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'43', u'43.1', 1193, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/43/43.2.csv / Remote: /home/abenassi/1194.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1194&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'43', u'43.2', 1194, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/44/44.1.csv / Remote: /home/abenassi/1195.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1195&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'44', u'44.1', 1195, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/44/44.2.csv / Remote: /home/abenassi/1196.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1196&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'44', u'44.2', 1196, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/45/45.1.csv / Remote: /home/abenassi/1197.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1197&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'45', u'45.1', 1197, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/45/45.2.csv / Remote: /home/abenassi/1198.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1198&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'45', u'45.2', 1198, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/46/46.1.csv / Remote: /home/abenassi/1199.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1199&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'46', u'46.1', 1199, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/46/46.2.csv / Remote: /home/abenassi/1200.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1200&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'46', u'46.2', 1200, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/47/47.1.csv / Remote: /home/abenassi/1201.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1201&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'47', u'47.1', 1201, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/47/47.2.csv / Remote: /home/abenassi/1202.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1202&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'47', u'47.2', 1202, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/48/48.1.csv / Remote: /home/abenassi/1203.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1203&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'48', u'48.1', 1203, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/48/48.2.csv / Remote: /home/abenassi/1204.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1204&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'48', u'48.2', 1204, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/49/49.1.csv / Remote: /home/abenassi/1205.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1205&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'49', u'49.1', 1205, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/49/49.2.csv / Remote: /home/abenassi/1206.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1206&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'49', u'49.2', 1206, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/50/50.1.csv / Remote: /home/abenassi/1207.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1207&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'50', u'50.1', 1207, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/50/50.2.csv / Remote: /home/abenassi/1208.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1208&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'50', u'50.2', 1208, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/51/51.1.csv / Remote: /home/abenassi/1209.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1209&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'51', u'51.1', 1209, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/51/51.2.csv / Remote: /home/abenassi/1210.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1210&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'51', u'51.2', 1210, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/52/52.1.csv / Remote: /home/abenassi/1211.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1211&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'52', u'52.1', 1211, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/52/52.2.csv / Remote: /home/abenassi/1212.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1212&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'52', u'52.2', 1212, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/53/53.1.csv / Remote: /home/abenassi/1213.csv
# (u'53', u'53.1', 1213, OSError(2, 'No such file or directory'))
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/54/54.1.csv / Remote: /home/abenassi/1214.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1214&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'54', u'54.1', 1214, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/54/54.2.csv / Remote: /home/abenassi/1215.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1215&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'54', u'54.2', 1215, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/55/55.1.csv / Remote: /home/abenassi/1216.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1216&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'55', u'55.1', 1216, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/56/56.1.csv / Remote: /home/abenassi/1217.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1217&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'56', u'56.1', 1217, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/56/56.2.csv / Remote: /home/abenassi/1218.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1218&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'56', u'56.2', 1218, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/57/57.1.csv / Remote: /home/abenassi/1219.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1219&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'57', u'57.1', 1219, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/58/58.1.csv / Remote: /home/abenassi/1220.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1220&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'58', u'58.1', 1220, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/59/59.1.csv / Remote: /home/abenassi/1221.csv
# ...
# (u'133', u'133.3', 1146, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/133/133.4.csv / Remote: /home/abenassi/1147.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1147&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'133', u'133.4', 1147, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/134/134.1.csv / Remote: /home/abenassi/1148.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1148&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'134', u'134.1', 1148, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/134/134.2.csv / Remote: /home/abenassi/1149.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1149&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'134', u'134.2', 1149, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/134/134.3.csv / Remote: /home/abenassi/1150.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1150&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'134', u'134.3', 1150, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/134/134.4.csv / Remote: /home/abenassi/1151.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1151&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'134', u'134.4', 1151, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/135/135.1.csv / Remote: /home/abenassi/1152.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1152&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'135', u'135.1', 1152, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/135/135.2.csv / Remote: /home/abenassi/1153.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1153&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'135', u'135.2', 1153, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/135/135.3.csv / Remote: /home/abenassi/1154.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1154&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'135', u'135.3', 1154, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/135/135.4.csv / Remote: /home/abenassi/1155.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1155&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'135', u'135.4', 1155, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/136/136.1.csv / Remote: /home/abenassi/1156.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1156&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'136', u'136.1', 1156, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/136/136.2.csv / Remote: /home/abenassi/1157.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1157&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'136', u'136.2', 1157, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/136/136.3.csv / Remote: /home/abenassi/1158.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1158&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'136', u'136.3', 1158, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/136/136.4.csv / Remote: /home/abenassi/1159.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1159&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'136', u'136.4', 1159, u'Halting')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/138/138.1.csv / Remote: /home/abenassi/1160.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1160&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'138', u'138.1', 1160, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/138/138.2.csv / Remote: /home/abenassi/1161.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1161&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'138', u'138.2', 1161, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/138/138.3.csv / Remote: /home/abenassi/1162.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1162&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'138', u'138.3', 1162, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/139/139.1.csv / Remote: /home/abenassi/1163.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1163&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'139', u'139.1', 1163, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/139/139.2.csv / Remote: /home/abenassi/1164.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1164&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'139', u'139.2', 1164, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/139/139.3.csv / Remote: /home/abenassi/1165.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1165&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'139', u'139.3', 1165, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/140/140.1.csv / Remote: /home/abenassi/1166.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1166&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'140', u'140.1', 1166, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/142/142.1.csv / Remote: /home/abenassi/1167.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1167&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'142', u'142.1', 1167, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/142/142.2.csv / Remote: /home/abenassi/1168.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1168&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'142', u'142.2', 1168, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/142/142.3.csv / Remote: /home/abenassi/1169.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1169&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'142', u'142.3', 1169, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/143/143.1.csv / Remote: /home/abenassi/1170.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1170&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'143', u'143.1', 1170, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/143/143.2.csv / Remote: /home/abenassi/1171.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1171&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'143', u'143.2', 1171, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/143/143.3.csv / Remote: /home/abenassi/1172.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1172&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'143', u'143.3', 1172, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/144/144.1.csv / Remote: /home/abenassi/1294.csv
# (u'144', u'144.1', 1294, OSError(2, 'No such file or directory'))
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/144/144.2.csv / Remote: /home/abenassi/1295.csv
# (u'144', u'144.2', 1295, OSError(2, 'No such file or directory'))
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/144/144.3.csv / Remote: /home/abenassi/1296.csv
# (u'144', u'144.3', 1296, OSError(2, 'No such file or directory'))
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/144/144.4.csv / Remote: /home/abenassi/1297.csv
# (u'144', u'144.4', 1297, OSError(2, 'No such file or directory'))
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/145/145.3.csv / Remote: /home/abenassi/1298.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1298&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'145', u'145.3', 1298, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/146/146.3.csv / Remote: /home/abenassi/1299.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1299&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'146', u'146.3', 1299, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/147/147.3.csv / Remote: /home/abenassi/1300.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1300&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'147', u'147.3', 1300, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/148/148.3.csv / Remote: /home/abenassi/1301.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1301&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'148', u'148.3', 1301, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/149/149.1.csv / Remote: /home/abenassi/1302.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1302&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'149', u'149.1', 1302, u'Stopped (with errors)')
# Local: /Users/abenassi/github/series-tiempo/catalogo/datos/datasets/150/150.1.csv / Remote: /home/abenassi/1303.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1303&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=
# (u'150', u'150.1', 1303, u'Stopped (with errors)')
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'11.2')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/42/42.2.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'124.2')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/42/42.1.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'79.2')", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'121.2')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/144/144.1.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'126.1')", 1)
# (u'Stopped (with errors)', 245)
# (u'Finished', 25)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/144/144.2.csv'", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/19/19.1.csv'", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/144/144.3.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'121.1')", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'122.1')", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'125.1')", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'99.1')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/93/93.1.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'109.1')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/59/59.1.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'109.2')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/144/144.4.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'99.2')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/53/53.1.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'11.1')", 1)
# (u'Halting', 5)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'92.1')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/34/34.1.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'79.1')", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'34.2')", 1)

# %%
for key in status_distributions:
    print(key, len(status_distributions[key]))
# Out:
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'11.2')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/42/42.2.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'124.2')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/42/42.1.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'79.2')", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'121.2')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/144/144.1.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'126.1')", 1)
# (u'Stopped (with errors)', 245)
# (u'Finished', 25)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/144/144.2.csv'", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/19/19.1.csv'", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/144/144.3.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'121.1')", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'122.1')", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'125.1')", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'99.1')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/93/93.1.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'109.1')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/59/59.1.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'109.2')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/144/144.4.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'99.2')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/53/53.1.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'11.1')", 1)
# (u'Halting', 5)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'92.1')", 1)
# ("[Errno 2] No such file or directory: '/Users/abenassi/github/series-tiempo/catalogo/datos/datasets/34/34.1.csv'", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'79.1')", 1)
# ("(u'Datos Programaci\\xf3n Macroecon\\xf3mica', u'34.2')", 1)

# %%
bs = upload_distribution_to_ind(
    "/Users/abenassi/github/series-tiempo/data/output/catalog/sspm/dataset/4/distribution/4.4/download/oferta-demanda-globales-precios-corrientes-valores-trimestrales-base-2004.csv", 
    "1081")
# Out:
# Local: /Users/abenassi/github/series-tiempo/data/output/catalog/sspm/dataset/4/distribution/4.4/download/oferta-demanda-globales-precios-corrientes-valores-trimestrales-base-2004.csv / Remote: /home/abenassi/1081.csv
# http://192.168.150.211:9080/pentaho-di/kettle/runJob/?job=public%2Fmetadata-dinamica%2Fjb_invocacion_api_ext&ID_DISTRIBUTION=1081&TOKEN=YWJlbmFzc2k6OjokMmEkMTAkWkJvOHJEOG9nbkJDSDB3dGFHREYxLkVLcVdoWUxPQzc1QXh3UDQxcFRtOFB4ZUVZdkdqNm0=

# %%
print(bs)
# Out:
# <?xml version="1.0" encoding="UTF-8"?><html><body><jobstatus>
# <jobname></jobname>
# <id>0256b302-8358-434d-b852-6e7262ecef9e</id>
# <status_desc>Stopped (with errors)</status_desc>
# <error_desc></error_desc>
# <logging_string>&lt;![CDATA[...]]&gt;</logging_string>
# <first_log_line_nr>0</first_log_line_nr>
# <last_log_line_nr>19217345</last_log_line_nr>
# <result><lines_input>0</lines_input>
# <lines_output>0</lines_output>
# <lines_read>0</lines_read>
# <lines_written>0</lines_written>
# <lines_updated>0</lines_updated>
# <lines_rejected>0</lines_rejected>
# <lines_deleted>0</lines_deleted>
# <nr_errors>1</nr_errors>
# <nr_files_retrieved>0</nr_files_retrieved>
# <entry_nr>2</entry_nr>
# <result>N</result>
# <exit_status>0</exit_status>
# <is_stopped>N</is_stopped>
# <log_channel_id>8d602b7d-fc56-42dd-9f60-24091553b9de</log_channel_id>
# <log_text>2017/08/22 19:06:48 - Abort job - ERROR (version 6.1.0.10-322, build 1 from 2017-01-20 12.32.47 by buildguy) : Aborting job.
# 2017/08/22 19:06:48 -  - ERROR: Problemas de autenticación
# 2017/08/22 19:06:48 -  - DESCRIPCION ERROR: Error de autenticación. Usuario y/o contraseña incorrecta
# 2017/08/22 19:06:48 - tr_autentica - Loading transformation from repository [tr_autentica] in directory [/public/metadata-dinamica/autenticacion]
# 2017/08/22 19:06:48 - tr_autentica - Dispatching started for transformation [tr_autentica]
# 2017/08/22 19:06:48 - ob_variable.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/22 19:06:48 - desencripto.0 - Optimization level set to 9.
# 2017/08/22 19:06:48 - in_listado_usuarios.0 - Finished reading query, closing connection.
# 2017/08/22 19:06:48 - in_listado_usuarios.0 - Finished processing (I=323, O=0, R=0, W=323, U=0, E=0)
# 2017/08/22 19:06:48 - desencripto.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/22 19:06:48 - parseo_usuario_clave.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/22 19:06:48 - flag_autentica.0 - Setting environment variables...
# 2017/08/22 19:06:48 - flag_autentica.0 - Set variable FLG_AUTENTICA to value [N]
# 2017/08/22 19:06:48 - flag_autentica.0 - Set variable ID_DISTRIBUTION to value [1081]
# 2017/08/22 19:06:48 - flag_autentica.0 - Set variable USUARIO to value [abenassi]
# 2017/08/22 19:06:48 - flag_autentica.0 - Set variable ESTADO to value [Problemas de autenticación]
# 2017/08/22 19:06:48 - flag_autentica.0 - Set variable MSG_ERROR to value [Error de autenticación. Usuario y/o contraseña incorrecta]
# 2017/08/22 19:06:48 - lk_usuarios.0 - Finished processing (I=0, O=0, R=324, W=1, U=0, E=0)
# 2017/08/22 19:06:48 - usuario_existe?.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/22 19:06:48 - set_flag invalido.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# 2017/08/22 19:06:48 - flag_autentica.0 - Finished after 1 rows.
# 2017/08/22 19:06:48 - flag_autentica.0 - Finished processing (I=0, O=0, R=1, W=1, U=0, E=0)
# null</log_text>
# </result></jobstatus>
# </body></html>

# %%
# sube catalogo
print(upload_datajson_to_ind(catalog_json_path))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-14-6f38ed02815e> in <module>()
#       1 # sube catalogo
# ----> 2 print(upload_datajson_to_ind(catalog_json_path))
#
# <ipython-input-8-7baa6d0d7221> in upload_datajson_to_ind(local_path, config_ind_path)
#       4         ind_params = yaml.load(f)
#       5
# ----> 6     upload_file_to_ind(local_path, config_ind=ind_params)
#       7
#       8     status = do_ind_api_request(req_type="metadata", config_ind=ind_params)
#
# <ipython-input-7-3421420cf01a> in upload_file_to_ind(local_path, remote_dir, file_name, config_ind)
#      24                 return res
#      25             else:
# ---> 26                 res = sftp.put(local_path)
#      27
#      28                 return res
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/pysftp/__init__.pyc in put(self, localpath, remotepath, callback, confirm, preserve_mtime)
#     362
#     363         sftpattrs = self._sftp.put(localpath, remotepath, callback=callback,
# --> 364                                    confirm=confirm)
#     365         if preserve_mtime:
#     366             self._sftp.utime(remotepath, times)
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/paramiko/sftp_client.pyc in put(self, localpath, remotepath, callback, confirm)
#     712         file_size = os.stat(localpath).st_size
#     713         with open(localpath, 'rb') as fl:
# --> 714             return self.putfo(fl, remotepath, file_size, callback, confirm)
#     715
#     716     def getfo(self, remotepath, fl, callback=None):
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/paramiko/sftp_client.pyc in putfo(self, fl, remotepath, file_size, callback, confirm)
#     668         .. versionadded:: 1.10
#     669         """
# --> 670         with self.file(remotepath, 'wb') as fr:
#     671             fr.set_pipelined(True)
#     672             size = self._transfer_with_callback(
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/paramiko/sftp_client.pyc in open(self, filename, mode, bufsize)
#     336             imode |= SFTP_FLAG_CREATE | SFTP_FLAG_EXCL
#     337         attrblock = SFTPAttributes()
# --> 338         t, msg = self._request(CMD_OPEN, filename, imode, attrblock)
#     339         if t != CMD_HANDLE:
#     340             raise SFTPError('Expected handle')
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/paramiko/sftp_client.pyc in _request(self, t, *arg)
#     765     def _request(self, t, *arg):
#     766         num = self._async_request(type(None), t, *arg)
# --> 767         return self._read_response(num)
#     768
#     769     def _async_request(self, fileobj, t, *arg):
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/paramiko/sftp_client.pyc in _read_response(self, waitfor)
#     817                 # synchronous
#     818                 if t == CMD_STATUS:
# --> 819                     self._convert_status(msg)
#     820                 return t, msg
#     821
#
# /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/paramiko/sftp_client.pyc in _convert_status(self, msg)
#     848             raise IOError(errno.ENOENT, text)
#     849         elif code == SFTP_PERMISSION_DENIED:
# --> 850             raise IOError(errno.EACCES, text)
#     851         else:
#     852             raise IOError(text)
#
# IOError: [Errno 13] Permission denied
# > /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/paramiko/sftp_client.py(850)_convert_status()
#     848             raise IOError(errno.ENOENT, text)
#     849         elif code == SFTP_PERMISSION_DENIED:
# --> 850             raise IOError(errno.EACCES, text)
#     851         else:
#     852             raise IOError(text)
#
# ipdb> u
# > /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/paramiko/sftp_client.py(819)_read_response()
#     817                 # synchronous
#     818                 if t == CMD_STATUS:
# --> 819                     self._convert_status(msg)
#     820                 return t, msg
#     821
#
# ipdb> u
# > /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/paramiko/sftp_client.py(767)_request()
#     765     def _request(self, t, *arg):
#     766         num = self._async_request(type(None), t, *arg)
# --> 767         return self._read_response(num)
#     768
#     769     def _async_request(self, fileobj, t, *arg):
#
# ipdb> u
# > /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/paramiko/sftp_client.py(338)open()
#     336             imode |= SFTP_FLAG_CREATE | SFTP_FLAG_EXCL
#     337         attrblock = SFTPAttributes()
# --> 338         t, msg = self._request(CMD_OPEN, filename, imode, attrblock)
#     339         if t != CMD_HANDLE:
#     340             raise SFTPError('Expected handle')
#
# ipdb> u
# > /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/paramiko/sftp_client.py(670)putfo()
#     668         .. versionadded:: 1.10
#     669         """
# --> 670         with self.file(remotepath, 'wb') as fr:
#     671             fr.set_pipelined(True)
#     672             size = self._transfer_with_callback(
#
# ipdb> u
# > /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/paramiko/sftp_client.py(714)put()
#     712         file_size = os.stat(localpath).st_size
#     713         with open(localpath, 'rb') as fl:
# --> 714             return self.putfo(fl, remotepath, file_size, callback, confirm)
#     715
#     716     def getfo(self, remotepath, fl, callback=None):
#
# ipdb> u
# > /Users/abenassi/anaconda/envs/series-tiempo/lib/python2.7/site-packages/pysftp/__init__.py(364)put()
#     362
#     363         sftpattrs = self._sftp.put(localpath, remotepath, callback=callback,
# --> 364                                    confirm=confirm)
#     365         if preserve_mtime:
#     366             self._sftp.utime(remotepath, times)
#
# ipdb> u
# > <ipython-input-7-3421420cf01a>(28)upload_file_to_ind()
#      24                 return res
#      25             else:
#      26                 res = sftp.put(local_path)
#      27
# ---> 28                 return res
#
# ipdb> local_path
# u'/Users/abenassi/github/series-tiempo/catalogo/datos/data.json'
